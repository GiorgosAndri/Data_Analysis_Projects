# %% [markdown]
# Australian domestic flights (FOR ASSESSMENT)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#       City1        City2  MonthNum  DistanceKm  AircraftTrips  Seats  \
# 0    ALBURY       SYDNEY         1         452            384  22933
# 1    ALBURY       SYDNEY         2         452            449  24735
# 2    ALBURY       SYDNEY         3         452            537  29026
# 3    ALBURY       SYDNEY         4         452            497  27213
# 4    ALBURY       SYDNEY         5         452            542  29204
# ..      ...          ...       ...         ...            ...    ...
# 835  SYDNEY  WAGGA WAGGA         8         367            474  24092
# 836  SYDNEY  WAGGA WAGGA         9         367            490  24520
# 837  SYDNEY  WAGGA WAGGA        10         367            503  25014
# 838  SYDNEY  WAGGA WAGGA        11         367            468  23364
# 839  SYDNEY  WAGGA WAGGA        12         367            392  20061
#
#      PassengerTrips
# 0             15654
# 1             15694
# 2             19333
# 3             19015
# 4             19771
# ..              ...
# 835           16546
# 836           16646
# 837           17146
# 838           16171
# 839           14009
#
# [840 rows x 7 columns]

# %% [markdown]
# 1)What were the 10 busiest routes for the year, measured by actual passenger trips, and how
# many actual passenger trips did they have?

# %%
#I create a new column that contains the routes, so I won't need to use City1 and City2.
df['route'] = df['City1'] + " " + df['City2']
result = pd.DataFrame(columns=['City1', 'City2', 'YearlyPassengerTrips'])

#I create a list of the routes in order to manage the index easier later.

routes = list(df['route'].value_counts().keys())
#I use a for loop in order to
#create one row dataframes of every route and I append it to the result dataframe.

for i in routes:
    
#Passenger Sum

    passengers = df.loc[df['route'] == i]['PassengerTrips'].sum()
    
    #City1 name
    
    City1 = df.loc[df['route'] == i, 'City1'].iloc[1]
    
    #City2 name
    
    City2 = df.loc[df['route'] == i, 'City2'].iloc[1]
    
    #single row dataframe
    add = pd.DataFrame({'City1': City1, 'City2':City2,
                        'YearlyPassengerTrips':passengers}, 
                       index=np.arange(routes.index(i),routes.index(i)+1))
    
    result = result.append(add)
    #Fixing index
result.index =np.arange(0, result.shape[0])
# Out:
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\970987367.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)

# %%
print("Top 10 busiest routes for the year")
result.sort_values('YearlyPassengerTrips', ascending=False).head(10)
# Out:
# Top 10 busiest routes for the year
#          City1       City2 YearlyPassengerTrips
# 30   MELBOURNE      SYDNEY              9181932
# 67    BRISBANE      SYDNEY              4821044
# 60    BRISBANE   MELBOURNE              3608681
# 28  GOLD COAST      SYDNEY              2733109
# 49    ADELAIDE   MELBOURNE              2538061
# 32   MELBOURNE  GOLD COAST              2122157
# 31   MELBOURNE       PERTH              2110125
# 44    ADELAIDE      SYDNEY              1878741
# 19       PERTH      SYDNEY              1692031
# 1       HOBART   MELBOURNE              1670181

# %% [markdown]
# For every route, what was their busiest month number, measured by actual passenger trips,
# and how many actual passenger trips did it have that month? (If there is no unique busiest
# month, any month will do.)

# %%
#Exact same method as before, but I use max() instead of sum() and different columns.

result = pd.DataFrame(columns=['City1', 'City2', 'BusiestMonth', 'NumTrips'])

#I create a list of the routes in order to manage the index easier later.

routes = list(df['route'].value_counts().keys())
#I use a for loop in order to
#create one row dataframes of every route and I append it to the result dataframe.

for i in routes:
    
    route = df.loc[df['route'] == i]
    route = route.loc[route['PassengerTrips'] == route['PassengerTrips'].max()]
    
    passengers = route['PassengerTrips'].iloc[0]
    #City1 name
    
    City1 = route['City1'].iloc[0]
    
    #City2 name
    City2 = route['City2'].iloc[0]
    #Month
    Month = route['MonthNum'].iloc[0]
    
    #single row dataframe
    add = pd.DataFrame({'City1': City1, 'City2':City2, 'BusiestMonth': Month,
                        'NumTrips':passengers}, 
                       index=np.arange(routes.index(i),routes.index(i)+1))
    
    result = result.append(add)
    #Fixing index
result.index =np.arange(0, result.shape[0])
# Out:
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3217666745.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)

# %%
print("Buisiest Month for every route")
result
# Out:
# Buisiest Month for every route
#          City1        City2 BusiestMonth NumTrips
# 0       ALBURY       SYDNEY           10    21479
# 1       HOBART    MELBOURNE            1   164170
# 2   LAUNCESTON    MELBOURNE            1    97718
# 3     KARRATHA        PERTH           10    43237
# 4   KALGOORLIE        PERTH           10    26547
# ..         ...          ...          ...      ...
# 65    BRISBANE   PROSERPINE           10    24769
# 66    BRISBANE  ROCKHAMPTON            7    50811
# 67    BRISBANE       SYDNEY           10   447595
# 68    BRISBANE   TOWNSVILLE            7    95192
# 69      SYDNEY  WAGGA WAGGA           10    17146
#
# [70 rows x 4 columns]

# %% [markdown]
# During which month number were there the most actual passenger trips in total across all
# routes?

# %%
result = pd.DataFrame(columns=['Month', 'TotalPassengerTrips'])

#I create a list of the routes in order to manage the index easier later.

months = list(df['MonthNum'].value_counts().keys())
#I use a for loop in order to
#create one row dataframes of every route and I append it to the result dataframe.

for i in months:
    
#Passenger Sum

    passengers = df.loc[df['MonthNum'] == i]['PassengerTrips'].sum()
    
    
    #single row dataframe
    add = pd.DataFrame({'Month': i,
                        'TotalPassengerTrips':passengers}, 
                       index=np.arange(months.index(i),months.index(i)+1))
    
    result = result.append(add)
    #Fixing index
result.index =np.arange(0, result.shape[0])
max_month = result[result['TotalPassengerTrips'] == result['TotalPassengerTrips'].max()]
# Out:
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\2705088909.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)

# %%
print('The overall busiest month: \n ', max_month['Month'].iloc[0], ": " ,
      max_month['TotalPassengerTrips'].iloc[0])
# Out:
# The overall busiest month:
#   10 :  5105125

# %% [markdown]
# What were the 10 routes that had the highest proportion of vacant seats during the year, and
# what were their proportions of vacancy?

# %%
result = pd.DataFrame(columns=['City1', 'City2', 'Vacancy'])

#I create a list of the routes in order to manage the index easier later.

routes = list(df['route'].value_counts().keys())
#I use a for loop in order to
#create one row dataframes of every route and I append it to the result dataframe.

for i in routes:
    
    #We divide the sum of the Passengers with the sum of the seats.
    #By this, we find the percentage of the passengers.
    #And we subtract 1 by the percentage of the passengers.
    #That way, we find the proportion of the vacant seats.
    percentage = 1 - df[df['route']==i]['PassengerTrips'].sum()/df[df['route']==i]['Seats'].sum()
    
    #City1 name
    
    City1 = df.loc[df['route'] == i, 'City1'].iloc[1]
    
    #City2 name
    
    City2 = df.loc[df['route'] == i, 'City2'].iloc[1]
    
    #single row dataframe
    add = pd.DataFrame({'City1': City1, 'City2':City2,
                        'Vacancy':percentage}, 
                       index=np.arange(routes.index(i),routes.index(i)+1))
    
    result = result.append(add)
    #Fixing index
result.index =np.arange(0, result.shape[0])
# Out:
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   percentage = 1 - df[df['route']==i]['PassengerTrips'].sum()/df[df['route']==i]['Seats'].sum()
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   percentage = 1 - df[df['route']==i]['PassengerTrips'].sum()/df[df['route']==i]['Seats'].sum()
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   percentage = 1 - df[df['route']==i]['PassengerTrips'].sum()/df[df['route']==i]['Seats'].sum()
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:15: RuntimeWarning: invalid value encountered in longlong_scalars
#   percentage = 1 - df[df['route']==i]['PassengerTrips'].sum()/df[df['route']==i]['Seats'].sum()
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)
# C:\Users\andri\AppData\Local\Temp\ipykernel_1128\3911601779.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(add)

# %%
print("The 10 routes with the highest proportion of vacant seats:")
result.sort_values('Vacancy', ascending=False).head(10)
# Out:
# The 10 routes with the highest proportion of vacant seats:
#             City1         City2   Vacancy
# 43  ALICE SPRINGS        DARWIN  0.565066
# 4      KALGOORLIE         PERTH  0.433001
# 14         CAIRNS    TOWNSVILLE  0.418525
# 8       GERALDTON         PERTH  0.412624
# 25          PERTH        NEWMAN   0.40672
# 46       ADELAIDE  PORT LINCOLN  0.397928
# 26          PERTH  PORT HEDLAND  0.370486
# 3        KARRATHA         PERTH   0.36032
# 21         SYDNEY      TAMWORTH  0.349407
# 27      MELBOURNE       MILDURA   0.33924
