# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %% [markdown]
# project : https://replit.com/@GiorgosAndrigia/boilerplate-sea-level-predictor#sea_level_predictor.py

# %%
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
fig = df.plot(kind='scatter', x='Year', y='CSIRO Adjusted Sea Level', figsize=(15,7))
plt.title('Rise in the sea level')
a = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
x = pd.Series(np.arange(1880, 2051))
y = a.intercept + a.slope*x
plt.plot(x, y, 'r')
df2 = df.loc[df['Year'] >= 2000]
a = linregress(df2['Year'], df2['CSIRO Adjusted Sea Level'])
x = pd.Series(np.arange(2000, 2051))
y = a.intercept + a.slope*x
plt.plot(x, y, 'y')
fig.set_ylabel('Sea level (inches)')
fig.set_xlabel('Year')
fig.set_title('Rise in the sea level')
# Out:
# Text(0.5, 1.0, 'Rise in the sea level')
